# %% [markdown]
# # Using Napari to visualize and interact with images

# %% [markdown]
# [Matplotlib](https://matplotlib.org/stable/gallery/index.html) is the most flexible and traditional library to display images, also in jupyter notebooks. There are other very good options like [seaborn](https://seaborn.pydata.org/), [plotly](https://plotly.com/python/) and [bokeh](https://docs.bokeh.org/en/latest/docs/gallery.html#standalone-examples), with different pros and cons.
#
# Regarding interaction, even though these libraries can be interative, [Napari](https://napari.org/gallery.html) stands out as a fast, interactive, multi-dimensional image viewer in Python.
#
# In this notebook, we will open a napari viewer from here, add images and perform some interactions with them.

# %% [markdown]
# ## Opening the napari Viewer

# %% [markdown]
# In order to open the viewer, we first have to import napari

# %%
import napari

# %% [markdown]
# For this demonstration, we will also import the function `nbscreenshot` to display screenshots from napari here in the notebook.

# %%
from napari.utils import nbscreenshot

# %% [markdown]
# Now, we can open the viewer with the following command:

# %%
viewer = napari.Viewer()
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1920x1080+9+38 (frame: 1938x1127+0+0) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 1920x1055+9+38 (frame: 1938x1102+0+0) margins: 9, 38, 9, 9 minimum size: 612x573 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=630,620 maxtrack=0,0)

# %% [markdown]
# Napari should open in a separated window. Some warning messages in the cell above are normal.
#
# Let's show a screenshot of the viewer here. We pass the variable viewer to the function.

# %%
nbscreenshot(viewer)

# %% [markdown]
# ## Opening images in napari from a notebook

# %% [markdown]
# Now, let's load some example images here and visualize them in napari.

# %%
import numpy as np
from skimage import data

# %% [markdown]
# We will open a 2D grayscale example image from scikit-image called `human_mitosis`.

# %%
image_human_mitosis = data.human_mitosis() # read the example image 'human_mitosis' from scikit-image
image_human_mitosis.shape
# Out:
# (512, 512)

# %% [markdown]
# To open an image in napari from a notebook, we use the command `add_image()` from the `viewer`.

# %%
viewer.add_image(image_human_mitosis)
# Out:
# <Image layer 'image_human_mitosis' at 0x238ec1f4730>

# %% [markdown]
# This adds the image as a `layer` in napari. The layers list can be seen at the bottom left of the screen. For now, we have a single image layer there. Let's take a new screenshot.

# %%
nbscreenshot(viewer)

# %% [markdown]
# ## Interacting with the image

# %% [markdown]
# In the viewer, we can interact with the image in several ways. We can zoom in/out with the mouse wheel for example.
#
# Also, we can change something in the viewer, like the colormap, and retrieve this change back in code. Before we do that, let's get the current colormap of this layer.

# %% [markdown]
# We have to follow a hierarchy to get to the image colormap:
#
#     1. `viewer`
#
#     2. `layers`
#
#     3. `colormap`
#
#     4. `name`
#
# So the command becomes:

# %%
current_colormap = viewer.layers[0].colormap.name
current_colormap
# Out:
# 'gray'

# %% [markdown]
# The `[0]` index means we are accesssing a property of the first layer.

# %% [markdown]
# Now we go to the napari viewer and select a different colormap.

# %%
nbscreenshot(viewer)

# %%
current_colormap = viewer.layers[0].colormap.name
current_colormap
# Out:
# 'gray'

# %% [markdown]
# ## Exercise 1
# Add the brick image below to the viewer and now do the other way around: by code, change the colormap to `red` and the opacity to `0.5`. Check the effects in the viewer.
#
# *Hint: you can access and modify the opacity in a similar fashion to the colormap:
#
#     1. viewer
#
#     2. layers
#
#     3. opacity

# %%
image_brick = data.brick()

# %%
image_brick_new = viewer.add_image(image_brick)
image_brick_new
# Out:
# <Image layer 'image_brick' at 0x238ec585820>

# %%
# current_colormap = 
viewer.layers['image_brick'].colormap =  'red'
# napari.view_image(image_brick_new, colormap='magma')

# %%
viewer.layers['image_brick'].opacity = 0.5
# Out:
# 2022-10-17 16:48:48.647 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gamma_correction (clesperanto)(..., 1.0)
# 2022-10-17 16:49:40.730 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-10-17 16:49:52.919 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.0, 1.0, 0.0)
# 2022-10-17 16:50:00.744 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.1, 1.0, 0.0)
# 2022-10-17 16:50:01.239 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.2000000000000002, 1.0, 0.0)
# 2022-10-17 16:50:01.396 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.3000000000000003, 1.0, 0.0)
# 2022-10-17 16:50:01.532 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.4000000000000004, 1.0, 0.0)
# 2022-10-17 16:50:01.675 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.5000000000000004, 1.0, 0.0)
# 2022-10-17 16:50:01.925 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.6000000000000005, 1.0, 0.0)
# 2022-10-17 16:50:02.091 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.7000000000000006, 1.0, 0.0)
# 2022-10-17 16:50:02.432 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.8000000000000007, 1.0, 0.0)
# 2022-10-17 16:50:02.578 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 1.9000000000000008, 1.0, 0.0)
# 2022-10-17 16:50:02.739 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.0, 0.0)
# 2022-10-17 16:50:03.505 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.1, 0.0)
# 2022-10-17 16:50:03.644 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.2000000000000002, 0.0)
# 2022-10-17 16:50:03.788 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.3000000000000003, 0.0)
# 2022-10-17 16:50:03.931 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.4000000000000004, 0.0)
# 2022-10-17 16:50:04.083 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.5000000000000004, 0.0)
# 2022-10-17 16:50:04.219 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.6000000000000005, 0.0)
# 2022-10-17 16:50:04.381 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.7000000000000006, 0.0)
# 2022-10-17 16:50:04.531 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.8000000000000007, 0.0)
# 2022-10-17 16:50:04.681 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 1.9000000000000008, 0.0)
# 2022-10-17 16:50:04.862 | INFO     | napari_assistant._gui._category_widget:call_op:174 - gaussian_blur (clesperanto)(..., 2.000000000000001, 2.000000000000001, 0.0)
